# %%
# opening the file in read mode
my_file = open("data/Roots_data_2021_2022.txt", "r")
  
# reading the file
data = my_file.read()
  
# replacing end of line('/n') with ' ' and
# splitting the text it further when '.' is seen.
data_into_list = data.replace('\n', ' ').split(".")
  
# printing the data
print(data_into_list)
my_file.close()
# Out:
# ['year\tCustomer\tAVA\tSensor_ID\tgrower_ID\tgrid\tCollection_start_date\tCollection_end_date\tDate_received\tj_date\tdays_sampled\treceived_to_result\tGPM\tspores\tlog_spores\tLatitude\tLongitude 2022\tGrapery\tBakersfield\tS53\tSW_Row_30\tout\t3/1/22\t3/3/22\t3/4/22\t22062\t2\t0\tNOT_DETECTED\t0\t0\t35', '1118\t-118', '876519 2022\tGrapery\tBakersfield\tS57\tSE_Row_85\tout\t3/1/22\t3/3/22\t3/4/22\t22062\t2\t0\tNOT_DETECTED\t0\t0\t35', '111775\t-118', '874323 2022\tGrapery\tBakersfield\tS60\tNE_Row_85\tout\t3/1/22\t3/3/22\t3/4/22\t22062\t2\t0\tNOT_DETECTED\t0\t0\t35', '113595\t-118', '874342 2022\tGrapery\tBakersfield\tS63\tNW_Row_30\tout\t3/1/22\t3/3/22\t3/4/22\t22062\t2\t0\tNOT_DETECTED\t0\t0\t35', '113601\t-118', '876485 2022\tGrapery\tBakersfield\tS57\tSE_Row_85\tout\t3/3/22\t3/7/22\t3/8/22\t22066\t4\t0\tNOT_DETECTED\t0\t0\t35', '111775\t-118', '874323 2022\tGrapery\tBakersfield\tS60\tNE_Row_85\tout\t3/3/22\t3/7/22\t3/8/22\t22066\t4\t0\tNOT_DETECTED\t0\t0\t35', '113595\t-118', '
# ...
